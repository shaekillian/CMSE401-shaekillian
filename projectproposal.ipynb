# %% [markdown]
# # OpenCV Parallel Computing Project Proposal
# ### Shae Killian

# %%
from IPython.display import display, Image

display(Image(filename="opencv-wallpaper.png", width=400, height=300))

# %% [markdown]
# ## Abstract
#
# For this project I intend to focus on analyzing OpenCV (Open Source Computer Vision Library), a widely used tool for computer vision and image processing. This software enables various applications, such as facial detection and recognition, object tracking, motion detection and video analysis, as well as augmented reality and edge/shape detection. These topics are related to the realm of artificial intelligence and machine learning, an area of computing that my career will be highly focused on, and therefore is my largest motivator in deciding my route for this project. I have great interest in using this project as an opportunity to not only gain experience working with this software, but to also further my understanding on the main themes of OpenCV and what it entails.
#
# Because OpenCV is optimized for image and video processing, it relies heavily on techniques such as NumPy-based matrix operations, pixel manipulation, and vectorized transformations. OpenCV is best used when run on multi-core CPUs and GPUs, which I will complete on the HPCC, using techniques such as OpenMP, CUDA, and OpenCL. Upon further research and testing I will decide what types of CPU and GPU I will implement.
#
# My bench-marking will focus on comparing performance of different image processing tasks (such as object detection, filtering, edge detection, etc.), on both a CPU and GPU, whilst using parallel computing operations such as OpenMP, CUDA, and/or OpenCL. The primary goals of this project are: to be able to demonstrate a quantifiable processing speedup, identify bottlenecks in the CPU process, and perform a possible GPU acceleration in order to improve speed as well. Although this is my goal as of right now, this is tentative depending on what we learn within the next few weeks during class, as these topics may shift my goals for this project.

# %% [markdown]
# ## Schedule
#
# Sunday February 9 - Project Proposal Milestone Due
#
# Week of February 10 - Research different GPU's and CPU's and their benefits/downsides
#
# Week of February 17 - Sections 1 and 2 of Part 1 requirements.
#
# Week of February 24 - Sections 3-5 of Part 1 requirements.
#
# Sunday February 26 - Project Part 1 Due
#
# Week of March 3 - Overview part 2 and outline steps I still need to complete/research
#
# Week of March 10 - Begin bench-marking
#
# Week of March 17 - Finish bench-marking, begin optimization
#
# Week of March 24 - Timing studies and complete timing results
#
# Week of April 1 - Begin final report/write-up
#
# Week of April 7 - Finalize any last minute ideas on report
#
# April 15 - Final Project due

# %% [markdown]
# ## Part 1 Software Exploration

# %% [markdown]
# According to Geeks For Geeks, OpenCV is "a huge open-source library for computer vision, machine learning, and image processing." Using this library allows users to process images and videos in order to identify a variety of objects, faces, handwriting, etc. When used in conjunction with other popular libraries such as NumPy, OpenCV's capabilities expand to an even larger list, allowing for array structure analysis and vector space operations. OpenCV is widely available for millions of users, as it is free for both academic and commercial use, due to its release under a BSD license. This library can be used with C, C++, Python, and Java interfaces, while also supporting its use through Windows, Linux, Mac OS, IOS, and Android.
#
# With Artificial Intelligence detection and a fast uprising in image/video prevalence in today's world, the capabilities of OpenCV have proven to become extremely helpful and desirable. Further provided by Geeks for Geeks is an extremely detailed list of real-world uses for OpenCV:
# - Face recognition
# - Automated inspection and surveillance
# - number of people – count (foot traffic in a mall, etc)
# - Vehicle counting on highways along with their speeds
# - Interactive art installations
# - Anomaly (defect) detection in the manufacturing process (the odd defective products)
# - Street view image stitching
# - Video/image search and retrieval
# - Robot and driver-less car navigation and control
# - object recognition
# - Medical image analysis
# - Movies – 3D structure from motion
# - TV Channels advertisement recognition
# Many of the examples above focus on reading images, which is done through methods of array interpretations, pixel values and intensity, image matrices, and image processing algorithms that are used to orchestrate these values into a visible image. In previous courses I have only familiarized myself lightly with the use of pixel processing to output images in Python, so using OpenCV for this project, I would love to compare the differences and see what is possible using its image capabilities.
#
# Although I know one of my focal points will be working with images in some way, I would like to determine the rest of my specific goals as I continue to further my research on OpenCV as a whole, and learn more about what I will be able to do with it. So far, I have found wonderful information at https://www.geeksforgeeks.org/opencv-overview/, https://opencv.org/, and https://blog.roboflow.com/what-is-opencv/, a beginners guide to OpenCV. I plan to research as much as I can using helper websites and examples, in order to determine definitively my goals for this project. Despite having open-ended goals for implementation, I am certain that I would prefer to provide a list of detailed instructions for running the code on the HPCC, rather than providing them in a folder format, as I find listed step-by-step instructions to be the most helpful when navigating a newer interface.

# %% [markdown]
# ## Part 2 Benchmark and Optimization

# %% [markdown]
# Explain what code you are going to benchmark. Do you know if it already can be run in parallel? If so what types of things are you going to look for to optimize the output of the software. How will you evaluate the software to know if the project is successful? What do you hope/expect to deliver and a successful outcome in your final report? For example, you plan to implement openmp and demonstrate 20 times speedup in the code or I plan to identify a bottleneck in the code and demonstrate a 4x speed up the slow.
#
# #### Bechmarking Process
# I plan to benchmark common OpenCV image processing jobs that are commonly used in real-world applications. These jobs may include edge detection, image filtering, and object detection. Upon further research I will be able to determine what exact steps are necessary for these jobs, however they will strongly benefit from parallel execution.
#
# #### Optimization
# I will first run my tasks on a CPU using the built-in functions of OpenCV, and later explore OpenMP to optimize performance using its multi-threaded methods. To compare, I will then run the same tasks using a GPU in conjunction with OpenCL or something similar, in order to influence parallel processing. I think comparing outputs and performance from different processing units will prove to be very telling in terms of code efficiency and optimization. I will measure these aspects by collecting execution times, ratio of CPU to GPU times, frame times, as well as resources, such as memory, cores and threads.
#
# Keeping these evaluation tactics in mind, I expect my outcomes to be able to identify any bottlenecks within the use of CPU or GPU based execution, to demonstrate any significant speedups in image processing, as well as be able to determine what steps are necessary for each task.
#
# #### Deliverables
# My final report will include performance comparison graphs, such as CPU vs GPU execution times, a detailed guide of instructions for running the benchmark on HPCC, an understanding on which tasks have the greatest benefit from GPU acceleration, as well as code implementations for both the CPU and GPU used. As the class progresses, it is possible my goals may change, as I learn more methods of parallelism.
